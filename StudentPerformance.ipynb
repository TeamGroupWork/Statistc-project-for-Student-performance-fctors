# %%
# # Load the necessary packages
import pandas as pd
import numpy as np

# %%
mydata = pd.read_csv('StudentPerformanceFactors.csv')

# %%
mydata.tail(5)

# %%
# Load the Cardio Dataset
mydata = pd.read_csv('StudentPerformanceFactors.csv')

# %%
# mydata.head()
# mydata.columns
mydata.info()

# %%
mydata.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

mydata.hist(figsize=(30,20))
plt.show()

# %%
import seaborn as sns

sns.boxplot(x="Gender", data=mydata)
# Out:
# <Axes: xlabel='Gender'>

# %%
pd.crosstab(mydata['Physical_Activity'],mydata['Gender'] )
# Out:
# Gender             Female  Male
# Physical_Activity
# 0                      22    24
# 1                     182   239
# 2                     688   939
# 3                    1064  1481
# 4                     676   899
# 5                     149   212
# 6                      12    20

# %%
sns.countplot(x="Motivation_Level", hue="Gender", data=mydata)
# Out:
# <Axes: xlabel='Motivation_Level', ylabel='count'>

# %%
pd.pivot_table(mydata, index=['Motivation_Level', 'Gender'],
                     columns=[ 'Peer_Influence'], aggfunc=len)
# Out:
#                         Access_to_Resources                  Attendance  \
# Peer_Influence                     Negative Neutral Positive   Negative
# Motivation_Level Gender
# High             Female                 114     208      226        114
#                  Male                   172     292      307        172
# Low              Female                 186     326      329        186
#                  Male                   231     411      454        231
# Medium           Female                 305     539      560        305
#                  Male                   369     816      762        369
#
#                                          Distance_from_Home                   \
# Peer_Influence          Neutral Positive           Negative Neutral Positive
# Motivation_Level Gender
# High             Female     208      226                114     208      226
#                  Male       292      307                172     292      307
# ...

# %%
pd.pivot_table(mydata,'Attendance', index=['Motivation_Level', 'Gender'],
                     columns=[ 'Peer_Influence'])
# Out:
# Peer_Influence            Negative    Neutral   Positive
# Motivation_Level Gender
# High             Female  80.438596  79.879808  79.247788
#                  Male    80.267442  79.678082  79.394137
# Low              Female  79.994624  80.579755  79.346505
#                  Male    79.861472  79.980535  79.867841
# Medium           Female  79.665574  80.345083  79.503571
#                  Male    79.189702  80.908088  80.143045

# %%
mydata['Physical_Activity'].std()
# Out:
# np.float64(1.0312310926271286)

# %%
mydata['Physical_Activity'].mean()
# Out:
# np.float64(2.9676101104888755)

# %%
sns.displot(mydata['Physical_Activity'])

# %%
mydata.hist(by='Gender',column = 'Motivation_Level')
# Out:
# array([<Axes: title={'center': 'Female'}>,
#        <Axes: title={'center': 'Male'}>], dtype=object)

# %%
mydata.hist(by='Gender',column = 'Attendance')
# Out:
# array([<Axes: title={'center': 'Female'}>,
#        <Axes: title={'center': 'Male'}>], dtype=object)

# %%
mydata.hist(by='Gender',column = 'Exam_Score')
# Out:
# array([<Axes: title={'center': 'Female'}>,
#        <Axes: title={'center': 'Male'}>], dtype=object)

# %%
mydata.hist(by='Motivation_Level',column = 'Exam_Score', figsize=(20,30))
# Out:
# array([[<Axes: title={'center': 'High'}>,
#         <Axes: title={'center': 'Low'}>],
#        [<Axes: title={'center': 'Medium'}>, <Axes: >]], dtype=object)

# %%
sns.pairplot(mydata)
